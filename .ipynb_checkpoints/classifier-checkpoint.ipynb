# %%
import keras
from keras.models import Sequential
from keras.layers import experimental
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.optimizers import SGD

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
# Init CNN
model = Sequential([
        experimental.preprocessing.RandomFlip("horizontal"),
        experimental.preprocessing.RandomRotation(0.1),
    ]
)

# %%
image_size = (256, 256)

# %%
model.add(Conv2D(32, 3, 3, input_shape=(256, 256, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Conv2D(64, 3, 3, input_shape=(256, 256, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(MaxPooling2D(pool_size=(2, 2))) # another pool fixes?

# %%
model.add(Flatten())

# %%
model.add(Dense(128, activation='relu'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
opt = SGD(lr=0.001)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
batch_size = 32

training_set = keras.preprocessing.image_dataset_from_directory(
    "dataset/training_set",
    validation_split=0.2,
    subset="training",
    seed=42069,
    image_size=image_size,
    batch_size=batch_size,
)
test_set = keras.preprocessing.image_dataset_from_directory(
    "dataset/training_set",
    validation_split=0.2,
    subset="validation",
    seed=42069,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 3392 files belonging to 2 classes.
# Using 2714 files for training.
# Found 3392 files belonging to 2 classes.
# Using 678 files for validation.

# %%
model.fit(training_set,
        epochs=30,
        validation_data=test_set,
        batch_size=batch_size)
# Out:
# Epoch 1/30
# 85/85 [==============================] - 33s 392ms/step - loss: 1.5720 - accuracy: 0.8552 - val_loss: 0.3446 - val_accuracy: 0.8997
# Epoch 2/30
# 85/85 [==============================] - 34s 395ms/step - loss: 0.3474 - accuracy: 0.8861 - val_loss: 0.3037 - val_accuracy: 0.9086
# Epoch 3/30
# 85/85 [==============================] - 32s 380ms/step - loss: 0.3308 - accuracy: 0.8817 - val_loss: 0.3603 - val_accuracy: 0.9027
# Epoch 4/30
# 85/85 [==============================] - 32s 373ms/step - loss: 0.3145 - accuracy: 0.8876 - val_loss: 0.3030 - val_accuracy: 0.9115
# Epoch 5/30
# 85/85 [==============================] - 32s 376ms/step - loss: 0.2831 - accuracy: 0.8957 - val_loss: 0.3343 - val_accuracy: 0.9086
# Epoch 6/30
# 85/85 [==============================] - 35s 408ms/step - loss: 0.2818 - accuracy: 0.8979 - val_loss: 0.2613 - val_accuracy: 0.9174
# Epoch 7/30
# 85/85 [==============================] - 33s 390ms/step - loss: 0.2623 - accuracy: 0.9083 - val_loss: 0.3565 - val_accuracy: 0.9041
# Epoch 8/30
# 85/85 [==============================] - 31s 366ms/step - loss: 0.2795 - accuracy: 0.8976 - val_loss: 0.2885 - val_accuracy: 0.8850
# Epoch 9/30
# 85/85 [==============================] - 31s 362ms/step - loss: 0.2583 - accuracy: 0.9042 - val_loss: 0.2643 - val_accuracy: 0.9218
# Epoch 10/30
# 85/85 [==============================] - 31s 362ms/step - loss: 0.2624 - accuracy: 0.9016 - val_loss: 0.2392 - val_accuracy: 0.9263
# Epoch 11/30
# 85/85 [==============================] - 31s 364ms/step - loss: 0.2488 - accuracy: 0.9153 - val_loss: 0.2510 - val_accuracy: 0.9218
# Epoch 12/30
# 85/85 [==============================] - 31s 362ms/step - loss: 0.2506 - accuracy: 0.9060 - val_loss: 0.3618 - val_accuracy: 0.8466
# Epoch 13/30
# 85/85 [==============================] - 31s 364ms/step - loss: 0.2478 - accuracy: 0.9130 - val_loss: 0.2321 - val_accuracy: 0.9277
# Epoch 14/30
# 85/85 [==============================] - 31s 365ms/step - loss: 0.2361 - accuracy: 0.9160 - val_loss: 0.2329 - val_accuracy: 0.9292
# Epoch 15/30
# 85/85 [==============================] - 31s 362ms/step - loss: 0.2293 - accuracy: 0.9175 - val_loss: 0.3070 - val_accuracy: 0.9100
# Epoch 16/30
# 85/85 [==============================] - 31s 365ms/step - loss: 0.2369 - accuracy: 0.9145 - val_loss: 0.2183 - val_accuracy: 0.9336
# Epoch 17/30
# 85/85 [==============================] - 31s 365ms/step - loss: 0.2276 - accuracy: 0.9208 - val_loss: 0.2137 - val_accuracy: 0.9351
# Epoch 18/30
# 85/85 [==============================] - 31s 364ms/step - loss: 0.2218 - accuracy: 0.9219 - val_loss: 0.2111 - val_accuracy: 0.9322
# Epoch 19/30
# 85/85 [==============================] - 31s 363ms/step - loss: 0.2246 - accuracy: 0.9234 - val_loss: 0.2795 - val_accuracy: 0.9130
# Epoch 20/30
# 85/85 [==============================] - 31s 364ms/step - loss: 0.2274 - accuracy: 0.9230 - val_loss: 0.2345 - val_accuracy: 0.9277
# Epoch 21/30
# 85/85 [==============================] - 31s 365ms/step - loss: 0.2204 - accuracy: 0.9252 - val_loss: 0.2162 - val_accuracy: 0.9336
# Epoch 22/30
# 85/85 [==============================] - 31s 364ms/step - loss: 0.2269 - accuracy: 0.9234 - val_loss: 0.2055 - val_accuracy: 0.9425
# Epoch 23/30
# 85/85 [==============================] - 31s 364ms/step - loss: 0.2053 - accuracy: 0.9300 - val_loss: 0.2045 - val_accuracy: 0.9381
# Epoch 24/30
# 85/85 [==============================] - 31s 365ms/step - loss: 0.2210 - accuracy: 0.9267 - val_loss: 0.2112 - val_accuracy: 0.9351
# Epoch 25/30
# 85/85 [==============================] - 31s 363ms/step - loss: 0.2109 - accuracy: 0.9282 - val_loss: 0.2028 - val_accuracy: 0.9366
# Epoch 26/30
# 85/85 [==============================] - 31s 364ms/step - loss: 0.2058 - accuracy: 0.9285 - val_loss: 0.2315 - val_accuracy: 0.9336
# Epoch 27/30
# 85/85 [==============================] - 31s 369ms/step - loss: 0.2117 - accuracy: 0.9241 - val_loss: 0.2492 - val_accuracy: 0.9233
# Epoch 28/30
# 85/85 [==============================] - 30s 353ms/step - loss: 0.2098 - accuracy: 0.9278 - val_loss: 0.2259 - val_accuracy: 0.9307
# Epoch 29/30
# 85/85 [==============================] - 30s 353ms/step - loss: 0.2144 - accuracy: 0.9307 - val_loss: 0.2387 - val_accuracy: 0.9292
# Epoch 30/30
# 85/85 [==============================] - 30s 357ms/step - loss: 0.1974 - accuracy: 0.9322 - val_loss: 0.2080 - val_accuracy: 0.9366

# %%
# Save the model
model.save('model')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: model/assets

# %%
# Test accuracy
results = model.evaluate(test_set, batch_size=64)
print("test loss/accuracy:", results)
# Out:
# 22/22 [==============================] - 3s 127ms/step - loss: 0.2080 - accuracy: 0.9366
# test loss/accuracy: [0.20804551243782043, 0.9365781545639038]

# %%
# Visualize
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

model = load_model('model')

for i in range(10):
    filename = 'dataset/examples/' + str(i) + '.jpg'
    test_img = image.load_img(filename, target_size=image_size)
    test_img = image.img_to_array(test_img)
    test_img = np.expand_dims(test_img, axis=0)
    
    result = model.predict(test_img)
    acc = result[0][0]
    is_pineapple = acc > 0.5
    label = 'Pineapple Pizza' if is_pineapple else 'Not Pineapple Pizza'
   
    img = mpimg.imread(filename)
    imgplot = plt.imshow(img)
    plt.text(x=0, y=-2, s= label + '(' + str(result[0][0]) + ')', fontsize=15)
    plt.show()
